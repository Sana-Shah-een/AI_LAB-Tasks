# %%
# !pip install transformers datasets evaluate rouge_score accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Collecting datasets
#   Downloading datasets-3.0.1-py3-none-any.whl.metadata (20 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.4.1+cu121)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# INFO: pip is looking at multiple versions of multiprocess to determine which version is compatible with other requirements. This could take a while.
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading datasets-3.0.1-py3-none-any.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 30.8 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=37fec3bbef579fb53c3d209e83d73986f8955a5fb4c5e57ca2f5c6d82eb84d05
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: xxhash, dill, rouge_score, multiprocess, datasets, evaluate
# Successfully installed datasets-3.0.1 dill-0.3.8 evaluate-0.4.3 multiprocess-0.70.16 rouge_score-0.1.2 xxhash-3.5.0

# %%
import transformers

transformers.__version__
# Out:
# '4.44.2'

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from huggingface_hub import list_datasets

datasets_list = list_datasets()

num = 0
for dataset in datasets_list:
  print(dataset)

  if (num > 10):
    break

  num += 1
# Out:
# DatasetInfo(id='google/frames-benchmark', author='google', sha='4f4c666ca0ca6997a1664e10217152d298e6d3c9', created_at=datetime.datetime(2024, 9, 19, 2, 15, 32, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 30, 15, 35, 13, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=373, downloads_all_time=None, likes=115, paperswithcode_id=None, tags=['language:en', 'license:apache-2.0', 'size_categories:n<1K', 'format:csv', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'arxiv:2409.12941', 'region:us', 'rag', 'long-context', 'llm-search', 'reasoning', 'factuality', 'retreival', 'question-answering', 'iterative-search'], card_data=None, siblings=None)
# DatasetInfo(id='openai/MMMLU', author='openai', sha='038c7808122969ead7456361af05cb8f47d247f8', created_at=datetime.datetime(2024, 9, 13, 16, 37, 19, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 10, 3, 16, 32, 33, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=3656, downloads_all_time=None, likes=365, paperswithcode_id=None, tags=['task_categories:question-answering', 'language:ar', 'language:bn', 'language:de', 'language:es', 'language:fr', 'language:hi', 'language:id', 'language:it', 'language:ja', 'language:ko', 'language:pt', 'language:sw', 'language:yo', 'language:zh', 'license:mit', 'size_categories:100K<n<1M', 'format:csv', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'library:polars', 'arxiv:2009.03300', 'region:us'], card_data=None, siblings=None)
# DatasetInfo(id='k-mktr/improved-flux-prompts-photoreal-portrait', author='k-mktr', sha='36cf6aac4216523e41c831517bc93ca42624cd58', created_at=datetime.datetime(2024, 9, 28, 8, 22, 13, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 10, 3, 10, 55, 26, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=24, downloads_all_time=None, likes=54, paperswithcode_id=None, tags=['task_categories:text-classification', 'language:en', 'license:mit', 'size_categories:10K<n<100K', 'format:parquet', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'region:us', 'art'], card_data=None, siblings=None)
# DatasetInfo(id='fka/awesome-chatgpt-prompts', author='fka', sha='459a66186f8f83020117b8acc5ff5af69fc95b45', created_at=datetime.datetime(2022, 12, 13, 23, 47, 45, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 3, 21, 28, 41, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=9198, downloads_all_time=None, likes=5801, paperswithcode_id=None, tags=['task_categories:question-answering', 'license:cc0-1.0', 'size_categories:n<1K', 'format:csv', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'region:us', 'ChatGPT'], card_data=None, siblings=None)
# DatasetInfo(id='HackerNoon/where-startups-trend', author='HackerNoon', sha='c4d39231116b3b9e2b136d44ac4d5ea33beb1945', created_at=datetime.datetime(2024, 7, 17, 19, 22, 3, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 30, 17, 28, 18, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=4, downloads_all_time=None, likes=35, paperswithcode_id=None, tags=['language:en', 'license:mit', 'size_categories:1M<n<10M', 'region:us', 'startup', 'startups', 'tech startups', 'technology startups', 'where startups trend', 'startups worldwide', 'startup by location', 'startup votes', 'voting data', 'startup voting data', 'tech voting data', 'technology voting data', 'hackernoon startups', 'hackernoon data', 'hackernoon voting', 'technology', 'hackernoon', 'san francisco startups', 'ai startups', 'ml startups', 'saas startups', 'new york startups', 'london startups', 'singapore startups', 'colorado startups', 'web3 startups', 'startups of the year', 'company', 'copmanies', 'tech company', 'tech companies', 'technology companies'], card_data=None, siblings=None)
# DatasetInfo(id='migtissera/Synthia-v1.5-I', author='migtissera', sha='e45080e1609f34c7a493b74700014dd2ebc95f26', created_at=datetime.datetime(2024, 9, 30, 1, 44, 18, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 30, 1, 48, 30, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=70, downloads_all_time=None, likes=35, paperswithcode_id=None, tags=['license:apache-2.0', 'size_categories:10K<n<100K', 'format:json', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'region:us'], card_data=None, siblings=None)
# DatasetInfo(id='argilla/FinePersonas-v0.1', author='argilla', sha='53f30d226c993ee059212a896cefdc14a1f9047f', created_at=datetime.datetime(2024, 9, 9, 14, 54, 1, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 18, 14, 59, 42, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=331, downloads_all_time=None, likes=295, paperswithcode_id=None, tags=['task_categories:text-generation', 'language:en', 'license:llama3', 'size_categories:10M<n<100M', 'format:parquet', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'library:polars', 'library:distilabel', 'arxiv:2406.20094', 'region:us', 'synthetic', 'distilabel'], card_data=None, siblings=None)
# DatasetInfo(id='FBK-MT/mosel', author='FBK-MT', sha='0f884d2d8ee47a646666e6407d340e38da62d82b', created_at=datetime.datetime(2024, 9, 23, 11, 1, 13, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 10, 2, 8, 44, 59, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=0, downloads_all_time=None, likes=26, paperswithcode_id=None, tags=['task_categories:automatic-speech-recognition', 'language:en', 'language:bg', 'language:hr', 'language:cs', 'language:da', 'language:nl', 'language:et', 'language:fi', 'language:fr', 'language:de', 'language:el', 'language:hu', 'language:ga', 'language:it', 'language:lv', 'language:lt', 'language:mt', 'language:pl', 'language:pt', 'language:ro', 'language:sk', 'language:sl', 'language:es', 'language:sv', 'license:cc-by-4.0', 'size_categories:10M<n<100M', 'format:csv', 'modality:image', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'library:polars', 'region:us'], card_data=None, siblings=None)
# DatasetInfo(id='glaiveai/reflection-v1', author='glaiveai', sha='6becaa822b43dfd79490bb8b41f3cdba194f7b64', created_at=datetime.datetime(2024, 9, 19, 18, 38, 59, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 19, 19, 8, 14, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=248, downloads_all_time=None, likes=22, paperswithcode_id=None, tags=['license:apache-2.0', 'size_categories:10K<n<100K', 'format:json', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'region:us'], card_data=None, siblings=None)
# DatasetInfo(id='SkunkworksAI/reasoning-0.01', author='SkunkworksAI', sha='7097753c0cd76874d3b60dbab4853830068fb98d', created_at=datetime.datetime(2024, 7, 5, 17, 37, 36, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 9, 14, 16, 6, 30, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=994, downloads_all_time=None, likes=242, paperswithcode_id=None, tags=['license:apache-2.0', 'size_categories:10K<n<100K', 'format:parquet', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'region:us'], card_data=None, siblings=None)
# DatasetInfo(id='lmms-lab/LLaVA-Video-178K', author='lmms-lab', sha='c0bca384313faa98bc4bff04db6b845d9954edb0', created_at=datetime.datetime(2024, 8, 27, 7, 9, 50, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 10, 4, 9, 20, 7, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=5, downloads_all_time=None, likes=25, paperswithcode_id=None, tags=['language:en', 'size_categories:1M<n<10M', 'modality:text', 'arxiv:2410.02713', 'region:us'], card_data=None, siblings=None)
# DatasetInfo(id='5CD-AI/Viet-LAION-Gemini-VQA', author='5CD-AI', sha='59fb508685df42be0af8b2a898507f82ed0bed39', created_at=datetime.datetime(2024, 9, 26, 7, 29, 52, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2024, 10, 3, 4, 32, 46, tzinfo=datetime.timezone.utc), private=False, gated='auto', disabled=False, downloads=86, downloads_all_time=None, likes=19, paperswithcode_id=None, tags=['task_categories:visual-question-answering', 'language:vi', 'size_categories:100K<n<1M', 'format:parquet', 'modality:image', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'library:polars', 'arxiv:2408.12480', 'region:us'], card_data=None, siblings=None)

# %%
from datasets import load_dataset

ds = load_dataset("microsoft/MeetingBank-QA-Summary")
ds
# Out:
# README.md:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/7.29M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/862 [00:00<?, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['idx', 'prompt', 'QA_pairs', 'summary', 'gpt4_summary'],
#         num_rows: 862
#     })
# })

# %%
ds.shape
# Out:
# {'test': (862, 5)}

# %%
ds['test'].features
# Out:
# {'idx': Value(dtype='int64', id=None),
#  'prompt': Value(dtype='string', id=None),
#  'QA_pairs': [{'answer': Value(dtype='string', id=None),
#    'question': Value(dtype='string', id=None)}],
#  'summary': Value(dtype='string', id=None),
#  'gpt4_summary': Value(dtype='string', id=None)}

# %%
ds['test'][0]
# Out:
# {'idx': 0,
#  'prompt': "The report of the Civil Rights, Utilities, Economic Development and Arts Committee Agenda Item three Resolution 31669 Encouraging as a best practice the use of an individualized tenant assessment using the Fair Housing Act's discriminatory effect standards to avoid Fair Housing Act violations when criminal history is used as a screening criterion in the Landlord Screening Process, Committee recommends that the resolution be adopted as amended grade. I move to amend Resolution 31669 by substituting D four for version D three, which includes a new attachment. A And I understand Councilmember Bagshaw also has an amendment, but let's first, if we could, let me just go through the changes to the resolution since the last committee meeting. The changes are found in two recitals, as well as sections one and five are the primary changes. We added a recital that again lifts up the HUD guidance to show that a criminal history screening policy is next must serve a substantial, legitimate and nondiscriminatory interest. Another recital we included was referencing the the Seattle Fair Chance Employment Ordinance and the way they approach some of these same issues, looking at making sure that individualized assessments and prohibiting questions on initial job applications regarding an applicant's criminal record. And then in Section one, and these are changes that we worked on with stakeholders together with councilmembers, the wants office desiring to really focus on not the the impacts of this particular resolution, but for what we hope to see in the future ordinance that is going to be coming to us to to regulate this area of of housing screening practices. And it identifies the principles that came out of the Hallow recommendations. And in Section five, again, this is just clarifying that the expectation in the HUD guidance is to distinguish between criminal conduct, that that indicates a demonstrable risk to residents safety and conduct that does not the resolution itself, whereas it's really focused on encouraging landlords to to follow HUD guidance that has been recently released regarding criminal records. The separate sections do. A couple of different things. Sections one and two, again, focus specifically on the future legislation that we expect to be coming out of the mayors task force. The. The next section basically says that we endorse practices that landlords should not automatically exclude individuals for housing on the basis of prior event arrests. The further sections refer refer to the process that the Office of Housing has facilitated to create procedures to select tenant screening agency guidelines for property management and affordable housing. Another section recommends that the that a landlord should not rely on records that cannot be reported by consumer reporting agencies under state law. And another section focuses on the Office of Civil Rights efforts to basically do enforcement of existing fair housing laws through testing, investigation of charges and other other means. The final section requests that as OCR when determining whether or not a complaint of housing discrimination based on the use of criminal history, whether or not there should they should it ask them to seek to determine whether or not there's a disparate impact? So that's an overview of both the resolution and the the changes that have been made since the committee discussion and vote on June 3rd. And I don't I may have started talking before I had a second. May I add a second? All right, great. Those in favor of supporting the substitute version D for 4d3ii in a OC. So we have the substitute amendment before us. Councilmember Bagshaw will move to further amend the resolution, but before consideration of the amendment, we have to move to suspend the rules because we've got we received the text for the amendment after the , I believe, noon deadline today. So I moved to suspend Council Rule three A6 relating to presentation of full c ...
#  'QA_pairs': [{'answer': 'Resolution 31669',
#    'question': 'What is the agenda item discussed in the meeting?'},
#   {'answer': 'Councilmember Bagshaw',
#    'question': 'Who has an amendment to the resolution?'},
#   {'answer': 'Fair housing laws',
#    'question': 'What does the Office of Civil Rights enforce?'}],
#  'summary': 'A RESOLUTION encouraging as a best practice the use of an individualized tenant assessment using the Fair Housing Act’s discriminatory effects standard to avoid Fair Housing Act violations when criminal history is used as a screening criterion in the landlord screening process.',
#  'gpt4_summary': "The Civil Rights, Utilities, Economic Development and Arts Committee discussed Resolution 31669, which encourages the use of an individualized tenant assessment using the Fair Housing Act's discriminatory effect standards to avoid violations when criminal history is used as a screening criterion in the Landlord Screening Process. The committee recommended adopting the resolution with amendments. The changes include adding a recital that a criminal history screening policy must serve a substantial, legitimate and nondiscriminatory interest, referencing the Seattle Fair Chance Employment Ordinance, and focusing on the impacts of the resolution on future housing screening practices. The resolution also encourages landlords to follow HUD guidance regarding criminal records and endorses practices that landlords should not automatically exclude individuals for housing based on prior arrests. Councilmember Bagshaw proposed an amendment to recognize the Certificate of Restoration of Opportunity, which provides concrete information about an individual who has served prison time to potential employers or housing providers. The resolution was adopted after a vote."}

# %%
def clean_txt(example):
    for txt in ["summary", "gpt4_summary"]:
        example[txt] = example[txt].lower()
        example[txt] = example[txt].replace("\\", "")  # Corrected for backslashes
        example[txt] = example[txt].replace("/", "")
        example[txt] = example[txt].replace("\n", "")
        example[txt] = example[txt].replace("``", "")
        example[txt] = example[txt].replace('"', '')
        example[txt] = example[txt].replace("--", "")

    return example

# %%
cleaned_ds = ds.map(clean_txt)
cleaned_ds
# Out:
# Map:   0%|          | 0/862 [00:00<?, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['idx', 'prompt', 'QA_pairs', 'summary', 'gpt4_summary'],
#         num_rows: 862
#     })
# })

# %%
# Access the 7th element from the 'summary' field in the 'test' split
ds['test']['summary'][7]
# Out:
# 'Recommendation to authorize City Manager, or designee, to execute all necessary documents to amend the U.S. Economic Development Administration (EDA) Revolving Loan Fund, to create the Long Beach Emergency Microenterprise Loan Program to assist local micro businesses impacted by the COVID-19 pandemic during the emergency declaration period.  (Citywide)'

# %%
cleaned_ds['test']['summary'][7]
# Out:
# 'recommendation to authorize city manager, or designee, to execute all necessary documents to amend the u.s. economic development administration (eda) revolving loan fund, to create the long beach emergency microenterprise loan program to assist local micro businesses impacted by the covid-19 pandemic during the emergency declaration period.  (citywide)'

# %%
ds['test']['gpt4_summary'][0]
# Out:
# "The Civil Rights, Utilities, Economic Development and Arts Committee discussed Resolution 31669, which encourages the use of an individualized tenant assessment using the Fair Housing Act's discriminatory effect standards to avoid violations when criminal history is used as a screening criterion in the Landlord Screening Process. The committee recommended adopting the resolution with amendments. The changes include adding a recital that a criminal history screening policy must serve a substantial, legitimate and nondiscriminatory interest, referencing the Seattle Fair Chance Employment Ordinance, and focusing on the impacts of the resolution on future housing screening practices. The resolution also encourages landlords to follow HUD guidance regarding criminal records and endorses practices that landlords should not automatically exclude individuals for housing based on prior arrests. Councilmember Bagshaw proposed an amendment to recognize the Certificate of Restoration of Opportunity, which provides concrete information about an individual who has served prison time to potential employers or housing providers. The resolution was adopted after a vote."

# %%
cleaned_ds['test']['gpt4_summary'][0]
# Out:
# "the civil rights, utilities, economic development and arts committee discussed resolution 31669, which encourages the use of an individualized tenant assessment using the fair housing act's discriminatory effect standards to avoid violations when criminal history is used as a screening criterion in the landlord screening process. the committee recommended adopting the resolution with amendments. the changes include adding a recital that a criminal history screening policy must serve a substantial, legitimate and nondiscriminatory interest, referencing the seattle fair chance employment ordinance, and focusing on the impacts of the resolution on future housing screening practices. the resolution also encourages landlords to follow hud guidance regarding criminal records and endorses practices that landlords should not automatically exclude individuals for housing based on prior arrests. councilmember bagshaw proposed an amendment to recognize the certificate of restoration of opportunity, which provides concrete information about an individual who has served prison time to potential employers or housing providers. the resolution was adopted after a vote."

# %%
EXAMPLE_TEXT_INDEX = 33

example_text = ds["test"]["summary"][EXAMPLE_TEXT_INDEX]

example_text
# Out:
# 'AN ORDINANCE relating to land use regulation of home occupations; extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with fewer limitations during the COVID-19 civil emergency; and ratifying and confirming certain prior acts.'

# %%
MODEL_NAME = "t5-small"

# %%
from transformers import pipeline

prefix = "summarize: "

summarizer = pipeline("summarization", model = MODEL_NAME)

summary_txt = summarizer(prefix + example_text)

summary_txt
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Your max_length is set to 200, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# [{'summary_text': 'extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with less limitations during the COVID-19 civil emergency . ratifying and confirming certain prior acts .'}]

# %%
summarizer = pipeline("summarization", model = MODEL_NAME, truncation=True)


summary_txt = summarizer(prefix + example_text)

summary_txt
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Your max_length is set to 200, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# [{'summary_text': 'extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with less limitations during the COVID-19 civil emergency . ratifying and confirming certain prior acts .'}]

# %%
ref_txt = ds["test"]["gpt4_summary"][EXAMPLE_TEXT_INDEX]

ref_txt
# Out:
# 'The meeting discussed two main items. The first was Council Bill 12265, which extends the policies for home-based businesses adopted last year under the Bringing Business Home legislation. This extension will allow departments to work on permanent regulations. The changes made it easier to operate a home-based business during the pandemic by easing restrictions, including removing the limit of two non-resident employees, removing the restriction that customers can only visit by appointment, and ending the requirement that businesses retain the appearance of a home. The bill passed with six in favor and one opposed. \n\nThe second item was Resolution 32048, which approves and ratifies the decision of the Metropolitan King County Council to adopt a revised set of countywide planning policies. The committee recommended the resolution be adopted.'

# %%
import evaluate

rouge = evaluate.load("rouge")

rouge
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# EvaluationModule(name: "rouge", module_type: "metric", features: [{'predictions': Value(dtype='string', id='sequence'), 'references': Sequence(feature=Value(dtype='string', id='sequence'), length=-1, id=None)}, {'predictions': Value(dtype='string', id='sequence'), 'references': Value(dtype='string', id='sequence')}], usage: """
# Calculates average rouge scores for a list of hypotheses and references
# Args:
#     predictions: list of predictions to score. Each prediction
#         should be a string with tokens separated by spaces.
#     references: list of reference for each prediction. Each
#         reference should be a string with tokens separated by spaces.
#     rouge_types: A list of rouge types to calculate.
#         Valid names:
#         `"rouge{n}"` (e.g. `"rouge1"`, `"rouge2"`) where: {n} is the n-gram based scoring,
#         `"rougeL"`: Longest common subsequence based scoring.
#         `"rougeLsum"`: rougeLsum splits text using `"
# "`.
#         See details in https://github.com/huggingface/datasets/issues/617
#     use_stemmer: Bool indicating whether Porter stemmer should be used to strip word suffixes.
#     use_aggregator: Return aggregates if this is set to True
# Returns:
#     rouge1: rouge_1 (f1),
#     rouge2: rouge_2 (f1),
#     rougeL: rouge_l (f1),
#     rougeLsum: rouge_lsum (f1)
# Examples:
#
#     >>> rouge = evaluate.load('rouge')
#     >>> predictions = ["hello there", "general kenobi"]
#     >>> references = ["hello there", "general kenobi"]
#     >>> results = rouge.compute(predictions=predictions, references=references)
#     >>> print(results)
#     {'rouge1': 1.0, 'rouge2': 1.0, 'rougeL': 1.0, 'rougeLsum': 1.0}
# """, stored examples: 0)

# %%
reference = "the elephant was found near the river and everyone was glad"

ex_1 = "the big elephant was found near the turbulent river and everyone was ecstatic"

ex_2 = "the big elephant was found near the river and made everyone glad"

# %%
results = rouge.compute(predictions = [ex_1], references = [reference])

results
# Out:
# {'rouge1': 0.8333333333333333,
#  'rouge2': 0.6363636363636365,
#  'rougeL': 0.8333333333333333,
#  'rougeLsum': 0.8333333333333333}

# %%
results = rouge.compute(predictions = [ex_2], references = [reference])

results
# Out:
# {'rouge1': 0.8695652173913043,
#  'rouge2': 0.5714285714285713,
#  'rougeL': 0.8695652173913043,
#  'rougeLsum': 0.8695652173913043}

# %%
summary_txt[0]["summary_text"]
# Out:
# 'extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with less limitations during the COVID-19 civil emergency . ratifying and confirming certain prior acts .'

# %%
result = rouge.compute(predictions = [summary_txt[0]["summary_text"]],
                       references = [ref_txt], use_stemmer = True)
result
# Out:
# {'rouge1': 0.2073170731707317,
#  'rouge2': 0.04938271604938272,
#  'rougeL': 0.12195121951219512,
#  'rougeLsum': 0.12195121951219512}

# %%
article_texts = ds["test"]["summary"]

article_summaries = ds["test"]["gpt4_summary"]

# %%
from tqdm import tqdm

candidate_summaries = []

prefix = "summarize: "

for i, text in enumerate(tqdm(article_texts[:50])):

    candidate = summarizer(prefix + text)

    candidate_summaries.append(candidate[0]["summary_text"])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]Your max_length is set to 200, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#   2%|▏         | 1/50 [00:02<01:57,  2.40s/it]Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
#   4%|▍         | 2/50 [00:04<01:39,  2.08s/it]Your max_length is set to 200, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#   8%|▊         | 4/50 [00:07<01:25,  1.87s/it]Your max_length is set to 200, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
#  10%|█         | 5/50 [00:09<01:18,  1.75s/it]Your max_length is set to 200, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
#  12%|█▏        | 6/50 [00:11<01:20,  1.83s/it]Your max_length is set to 200, but your input_length is only 33. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  14%|█▍        | 7/50 [00:13<01:22,  1.91s/it]Your max_length is set to 200, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
#  16%|█▌        | 8/50 [00:16<01:34,  2.25s/it]Your max_length is set to 200, but your input_length is only 187. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
#  18%|█▊        | 9/50 [00:19<01:46,  2.61s/it]Your max_length is set to 200, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
#  22%|██▏       | 11/50 [00:25<01:56,  2.99s/it]Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  24%|██▍       | 12/50 [00:27<01:40,  2.64s/it]Your max_length is set to 200, but your input_length is only 34. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
#  26%|██▌       | 13/50 [00:29<01:28,  2.40s/it]Your max_length is set to 200, but your input_length is only 176. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
#  28%|██▊       | 14/50 [00:31<01:24,  2.35s/it]Your max_length is set to 200, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
#  30%|███       | 15/50 [00:33<01:14,  2.13s/it]Your max_length is set to 200, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
#  32%|███▏      | 16/50 [00:35<01:09,  2.04s/it]Your max_length is set to 200, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#  34%|███▍      | 17/50 [00:36<01:02,  1.89s/it]Your max_length is set to 200, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
#  36%|███▌      | 18/50 [00:38<00:58,  1.83s/it]Your max_length is set to 200, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  38%|███▊      | 19/50 [00:40<00:57,  1.86s/it]Your max_length is set to 200, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
#  40%|████      | 20/50 [00:43<01:05,  2.18s/it]Your max_length is set to 200, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
#  42%|████▏     | 21/50 [00:45<01:05,  2.26s/it]Your max_length is set to 200, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
#  44%|████▍     | 22/50 [00:47<00:59,  2.12s/it]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
#  46%|████▌     | 23/50 [00:49<00:55,  2.06s/it]Your max_length is set to 200, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
#  48%|████▊     | 24/50 [00:52<01:00,  2.31s/it]Your max_length is set to 200, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
#  50%|█████     | 25/50 [00:55<00:59,  2.40s/it]Your max_length is set to 200, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
#  52%|█████▏    | 26/50 [00:58<01:04,  2.67s/it]Your max_length is set to 200, but your input_length is only 28. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
#  54%|█████▍    | 27/50 [01:00<00:57,  2.50s/it]Your max_length is set to 200, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
#  56%|█████▌    | 28/50 [01:01<00:48,  2.21s/it]Your max_length is set to 200, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
#  58%|█████▊    | 29/50 [01:03<00:42,  2.02s/it]Your max_length is set to 200, but your input_length is only 148. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
#  60%|██████    | 30/50 [01:06<00:45,  2.28s/it]Your max_length is set to 200, but your input_length is only 27. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
#  62%|██████▏   | 31/50 [01:08<00:40,  2.15s/it]Your max_length is set to 200, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
#  64%|██████▍   | 32/50 [01:10<00:38,  2.12s/it]Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
#  66%|██████▌   | 33/50 [01:12<00:38,  2.25s/it]Your max_length is set to 200, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
#  68%|██████▊   | 34/50 [01:15<00:35,  2.21s/it]Your max_length is set to 200, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
#  70%|███████   | 35/50 [01:16<00:32,  2.14s/it]Your max_length is set to 200, but your input_length is only 159. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
#  72%|███████▏  | 36/50 [01:18<00:29,  2.10s/it]Your max_length is set to 200, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
#  74%|███████▍  | 37/50 [01:21<00:28,  2.19s/it]Your max_length is set to 200, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
#  76%|███████▌  | 38/50 [01:23<00:26,  2.23s/it]Your max_length is set to 200, but your input_length is only 33. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  78%|███████▊  | 39/50 [01:25<00:24,  2.21s/it]Your max_length is set to 200, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
#  82%|████████▏ | 41/50 [01:32<00:26,  2.99s/it]Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  84%|████████▍ | 42/50 [01:34<00:20,  2.53s/it]Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  86%|████████▌ | 43/50 [01:36<00:17,  2.52s/it]Your max_length is set to 200, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
#  88%|████████▊ | 44/50 [01:39<00:15,  2.51s/it]Your max_length is set to 200, but your input_length is only 102. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
#  90%|█████████ | 45/50 [01:42<00:13,  2.65s/it]Your max_length is set to 200, but your input_length is only 153. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=76)
#  92%|█████████▏| 46/50 [01:45<00:11,  2.79s/it]Your max_length is set to 200, but your input_length is only 176. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
#  94%|█████████▍| 47/50 [01:48<00:08,  3.00s/it]Your max_length is set to 200, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
#  96%|█████████▌| 48/50 [01:51<00:05,  2.86s/it]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
#  98%|█████████▊| 49/50 [01:53<00:02,  2.69s/it]Your max_length is set to 200, but your input_length is only 42. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# 100%|██████████| 50/50 [01:55<00:00,  2.30s/it]

# %%
result_agg = rouge.compute(predictions = candidate_summaries,
                           references = article_summaries[:50],
                           use_stemmer = True)
result_agg
# Out:
# {'rouge1': 0.22176699536738248,
#  'rouge2': 0.11476658779433555,
#  'rougeL': 0.17036450866672465,
#  'rougeLsum': 0.1717253655996726}

# %%
result_unagg = rouge.compute(predictions = candidate_summaries,
                             references = article_summaries[:50],
                             use_stemmer = True,
                             use_aggregator = False)
result_unagg
# Out:
# {'rouge1': [0.23913043478260868,
#   0.26993865030674846,
#   0.22448979591836735,
#   0.09473684210526316,
#   0.23841059602649006,
#   0.24050632911392403,
#   0.16666666666666669,
#   0.3134328358208955,
#   0.2738095238095238,
#   0.15942028985507245,
#   0.41573033707865165,
#   0.2162162162162162,
#   0.2608695652173913,
#   0.14634146341463414,
#   0.11320754716981132,
#   0.2368421052631579,
#   0.1839080459770115,
#   0.32116788321167883,
#   0.22916666666666663,
#   0.2459893048128342,
#   0.3185840707964602,
#   0.25698324022346364,
#   0.09137055837563451,
#   0.26285714285714284,
#   0.1595744680851064,
#   0.2857142857142857,
#   0.21568627450980393,
#   0.12658227848101267,
#   0.2112676056338028,
#   0.16,
#   0.25925925925925924,
#   0.13658536585365855,
#   0.2896551724137931,
#   0.2073170731707317,
#   0.27142857142857146,
#   0.15384615384615385,
#   0.22891566265060243,
#   0.12578616352201258,
#   0.32298136645962733,
#   0.27218934911242604,
#   0.18556701030927836,
#   0.25287356321839083,
#   0.36496350364963503,
#   0.05970149253731343,
#   0.29166666666666663,
#   0.186046511627907,
#   0.16091954022988506,
#   0.248062015503876,
#   0.1774193548387097,
#   0.1895734597156398],
#  'rouge2': [0.18681318681318682,
#   0.14906832298136644,
#   0.10416666666666667,
#   0.05319148936170213,
#   0.13422818791946306,
#   0.1282051282051282,
#   0.0923076923076923,
#   0.2424242424242424,
#   0.13253012048192772,
#   0.04411764705882353,
#   0.1590909090909091,
#   0.13698630136986303,
#   0.17699115044247787,
#   0.0,
#   0.025477707006369428,
#   0.09333333333333334,
#   0.04651162790697674,
#   0.23703703703703705,
#   0.14736842105263157,
#   0.17297297297297298,
#   0.23423423423423423,
#   0.16949152542372883,
#   0.020512820512820516,
#   0.08092485549132948,
#   0.043010752688172046,
#   0.21649484536082475,
#   0.1386138613861386,
#   0.07692307692307691,
#   0.1285714285714286,
#   0.04040404040404041,
#   0.175,
#   0.029556650246305417,
#   0.12587412587412586,
#   0.04938271604938272,
#   0.13043478260869565,
#   0.015625,
#   0.0975609756097561,
#   0.03821656050955414,
#   0.23899371069182387,
#   0.1916167664670659,
#   0.010416666666666666,
#   0.19767441860465118,
#   0.3111111111111111,
#   0.0,
#   0.09859154929577466,
#   0.05633802816901408,
#   0.023255813953488375,
#   0.1889763779527559,
#   0.03278688524590164,
#   0.12440191387559811],
#  'rougeL': [0.1956521739130435,
#   0.2085889570552147,
#   0.1836734693877551,
#   0.09473684210526316,
#   0.1456953642384106,
#   0.18987341772151897,
#   0.1515151515151515,
#   0.23880597014925373,
#   0.21428571428571427,
#   0.10144927536231885,
#   0.23595505617977527,
#   0.14864864864864866,
#   0.2434782608695652,
#   0.12195121951219512,
#   0.07547169811320754,
#   0.17105263157894737,
#   0.11494252873563218,
#   0.291970802919708,
#   0.20833333333333331,
#   0.21390374331550804,
#   0.24778761061946902,
#   0.1787709497206704,
#   0.08121827411167512,
#   0.14857142857142858,
#   0.10638297872340426,
#   0.2653061224489796,
#   0.18627450980392157,
#   0.12658227848101267,
#   0.18309859154929575,
#   0.11000000000000001,
#   0.20987654320987653,
#   0.0975609756097561,
#   0.15172413793103448,
#   0.12195121951219512,
#   0.17142857142857143,
#   0.0923076923076923,
#   0.1686746987951807,
#   0.0880503144654088,
#   0.28571428571428575,
#   0.2485207100591716,
#   0.11340206185567012,
#   0.21839080459770116,
#   0.3503649635036496,
#   0.05970149253731343,
#   0.19444444444444445,
#   0.13023255813953488,
#   0.10344827586206898,
#   0.23255813953488372,
#   0.14516129032258066,
#   0.15165876777251183],
#  'rougeLsum': [0.1956521739130435,
#   0.2085889570552147,
#   0.1836734693877551,
#   0.09473684210526316,
#   0.1456953642384106,
#   0.18987341772151897,
#   0.1515151515151515,
#   0.23880597014925373,
#   0.21428571428571427,
#   0.10144927536231885,
#   0.23595505617977527,
#   0.14864864864864866,
#   0.2434782608695652,
#   0.12195121951219512,
#   0.07547169811320754,
#   0.17105263157894737,
#   0.11494252873563218,
#   0.291970802919708,
#   0.20833333333333331,
#   0.21390374331550804,
#   0.24778761061946902,
#   0.1787709497206704,
#   0.08121827411167512,
#   0.14857142857142858,
#   0.10638297872340426,
#   0.2653061224489796,
#   0.18627450980392157,
#   0.12658227848101267,
#   0.18309859154929575,
#   0.11000000000000001,
#   0.2345679012345679,
#   0.0975609756097561,
#   0.15172413793103448,
#   0.12195121951219512,
#   0.18571428571428572,
#   0.0923076923076923,
#   0.1686746987951807,
#   0.0880503144654088,
#   0.28571428571428575,
#   0.2485207100591716,
#   0.11340206185567012,
#   0.21839080459770116,
#   0.3503649635036496,
#   0.05970149253731343,
#   0.19444444444444445,
#   0.13953488372093023,
#   0.10344827586206898,
#   0.23255813953488372,
#   0.14516129032258066,
#   0.15165876777251183]}

# %%
import numpy as np

result_unagg_rsum = np.array(result_unagg["rouge2"])

np.argmax(result_unagg_rsum), np.argmin(result_unagg_rsum)
# Out:
# (42, 13)

# %%
import pandas as pd

act_vs_pred_summaries_df = pd.DataFrame(list(zip(candidate_summaries, article_summaries[:50])),
                                        columns = ["Predicted_Summaries", "Reference_summaries"])
act_vs_pred_summaries_df.head()
# Out:
#                                  Predicted_Summaries  \
# 0  a RESOLUTION encouraging as a best practice th...
# 1  this authorization applies to contracts for go...
# 2  resolution appoints certain properties within ...
# 3  a new concurrency test results map has been ad...
# 4  a ORDINANCE relating to the department of park...
#
#                                  Reference_summaries
# 0  The Civil Rights, Utilities, Economic Developm...
# 1  The Committee on Government Operations discuss...
# 2  The City Manager recommended the adoption of t...
# 3  The meeting discussed proposed ordinance 2016 ...
# 4  The meeting discussed the confirmation of an a...

# %%
print("Actual Summary")
print(act_vs_pred_summaries_df._get_value(42, "Predicted_Summaries"))

print("Reference Summary")
print(act_vs_pred_summaries_df._get_value(42, "Reference_summaries"))
# Out:
# Actual Summary
# city manager to direct airport director to provide a report on how the city will participate in discussions with the FAA to reduce helicopter noise .
# Reference Summary
# The meeting discussed the issue of helicopter noise in the City of Long Beach. Councilwoman Jeri Ships Key and Councilmember Gary DeLong recommended that the city manager direct the airport director to provide a report on how the city will participate in discussions with the FAA to reduce helicopter noise. This comes after the Los Angeles County Residential Helicopter Noise Relief Act was signed into law by President Obama, requiring the FAA to explore ways to reduce helicopter noise in Los Angeles County. A resident, Diamond Sievers, expressed her support for the motion and urged the council to actively participate in the upcoming FAA meetings. The motion was passed with seven votes.

# %%
print("Actual Summary")
print(act_vs_pred_summaries_df._get_value(13, "Predicted_Summaries"))

print("Reference Summary")
print(act_vs_pred_summaries_df._get_value(13, "Reference_summaries"))
# Out:
# Actual Summary
# Paradies Lagardere @ DEN 2017, LLC approves a proposed standard concession agreement . the agreement is a seven-year contract with the City and County of Denver .
# Reference Summary
# The meeting discussed a public debate scheduled for the following week. Councilman Cashman expressed his gratitude and congratulations to Denver International Airport for supporting local businesses, particularly small restaurants, amidst the rise of large chains. He highlighted the airport's high passenger traffic, which provides significant exposure for these businesses, and encouraged the continuation of such support.

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
tokenizer(["four-time defending champion"])
# Out:
# {'input_ids': [[662, 18, 715, 3, 20309, 6336, 1]], 'attention_mask': [[1, 1, 1, 1, 1, 1, 1]]}

# %%
tokens = tokenizer.tokenize("four-time defending champion")

tokens
# Out:
# ['▁four', '-', 'time', '▁', 'defending', '▁champion']

# %%
ids = tokenizer.convert_tokens_to_ids(tokens)

ids
# Out:
# [662, 18, 715, 3, 20309, 6336]

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_NAME)

# %%
prefix = "summarize: "


def preprocess_function(examples):

    inputs = [prefix + doc for doc in examples["summary"]]
    model_inputs = tokenizer(inputs, max_length = 1024, truncation = True)

    labels = tokenizer(text_target = examples["gpt4_summary"], max_length = 128, truncation = True)

    model_inputs["labels"] = labels["input_ids"]

    return model_inputs

# %%
tokenized_ds = cleaned_ds.map(preprocess_function, batched = True)

tokenized_ds
# Out:
# Map:   0%|          | 0/862 [00:00<?, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['idx', 'prompt', 'QA_pairs', 'summary', 'gpt4_summary', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 862
#     })
# })

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer, model = MODEL_NAME)

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens = True)

    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens = True)

    result = rouge.compute(predictions = decoded_preds, references = decoded_labels, use_stemmer = True)

    prediction_length = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["generated_length"] = np.mean(prediction_length)

    return {k: round(v, 4) for k, v in result.items()}

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="meetingbank_summary_model_finetuned_on_reduced_data",  # Removed trailing space
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=3,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=True,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds['test'],  # Using 'test' for training as well
    eval_dataset=tokenized_ds['test'],    # Using 'test' for evaluation
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
#     <div>
#
#       <progress value='162' max='162' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [162/162 01:47, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Generated Length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>3.559299</td>
#       <td>0.165000</td>
#       <td>0.085800</td>
#       <td>0.140800</td>
#       <td>0.140900</td>
#       <td>18.971000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>3.416718</td>
#       <td>0.167800</td>
#       <td>0.086800</td>
#       <td>0.144200</td>
#       <td>0.144300</td>
#       <td>18.995400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>3.383635</td>
#       <td>0.169900</td>
#       <td>0.087300</td>
#       <td>0.146200</td>
#       <td>0.146300</td>
#       <td>18.995400</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# TrainOutput(global_step=162, training_loss=3.899807400173611, metrics={'train_runtime': 109.496, 'train_samples_per_second': 23.617, 'train_steps_per_second': 1.48, 'total_flos': 154450900746240.0, 'train_loss': 3.899807400173611, 'epoch': 3.0})

# %%
trainer.push_to_hub()
# Out:
# events.out.tfevents.1728110178.80e9c7e300d6.959.0:   0%|          | 0.00/7.93k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Sanashaheen/meetingbank_summary_model_finetuned_on_reduced_data/commit/37c66679f4bd8fc2965a34f78edf0c49267c152c', commit_message='End of training', commit_description='', oid='37c66679f4bd8fc2965a34f78edf0c49267c152c', pr_url=None, pr_revision=None, pr_num=None)

# %%
example_text
# Out:
# 'AN ORDINANCE relating to land use regulation of home occupations; extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with fewer limitations during the COVID-19 civil emergency; and ratifying and confirming certain prior acts.'

# %%
from transformers import pipeline

prefix = "summarize: "

summarizer = pipeline(
    "summarization",
    model = "Sanashaheen/meetingbank_summary_model_finetuned_on_reduced_data",
    truncation=True
)
summary_txt = summarizer(prefix + example_text)

summary_txt
# Out:
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Your max_length is set to 200, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# [{'summary_text': 'extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with less limitations during the COVID-19 civil emergency . ratifying and confirming certain prior acts .'}]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Sanashaheen/meetingbank_summary_model_finetuned_on_reduced_data")

inputs = tokenizer(prefix + example_text, return_tensors = "pt", truncation=True).input_ids

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("Sanashaheen/meetingbank_summary_model_finetuned_on_reduced_data")

outputs = model.generate(inputs, max_new_tokens = 100, do_sample = False)

tokenizer.decode(outputs[0], skip_special_tokens = True)
# Out:
# 'a recommand relating to land use regulation of home occupations. extending for six months interim development controls established by Ordinance 126293 to allow home-based businesses to operate with less limitations during the COVID-19 civil emergency. a recommand relating to land use regulation of home occupations.'

# %%
ref_txt
# Out:
# 'The meeting discussed two main items. The first was Council Bill 12265, which extends the policies for home-based businesses adopted last year under the Bringing Business Home legislation. This extension will allow departments to work on permanent regulations. The changes made it easier to operate a home-based business during the pandemic by easing restrictions, including removing the limit of two non-resident employees, removing the restriction that customers can only visit by appointment, and ending the requirement that businesses retain the appearance of a home. The bill passed with six in favor and one opposed. \n\nThe second item was Resolution 32048, which approves and ratifies the decision of the Metropolitan King County Council to adopt a revised set of countywide planning policies. The committee recommended the resolution be adopted.'

# %%
result = rouge.compute(predictions = [summary_txt[0]["summary_text"]],
                       references = [ref_txt], use_stemmer = True)
result
# Out:
# {'rouge1': 0.2073170731707317,
#  'rouge2': 0.04938271604938272,
#  'rougeL': 0.12195121951219512,
#  'rougeLsum': 0.12195121951219512}

# %%
candidate_summaries = []

for i, text in enumerate(tqdm(article_texts[:50])):

  candidate = summarizer(prefix + text)

  candidate_summaries.append(candidate[0]["summary_text"])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]Your max_length is set to 200, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#   2%|▏         | 1/50 [00:04<03:40,  4.50s/it]Your max_length is set to 200, but your input_length is only 146. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
#   4%|▍         | 2/50 [00:07<02:39,  3.33s/it]Your max_length is set to 200, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
#   8%|▊         | 4/50 [00:14<02:46,  3.61s/it]Your max_length is set to 200, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
#  10%|█         | 5/50 [00:16<02:15,  3.00s/it]Your max_length is set to 200, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
#  12%|█▏        | 6/50 [00:20<02:25,  3.32s/it]Your max_length is set to 200, but your input_length is only 33. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  14%|█▍        | 7/50 [00:26<02:58,  4.15s/it]Your max_length is set to 200, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
#  16%|█▌        | 8/50 [00:30<02:46,  3.96s/it]Your max_length is set to 200, but your input_length is only 187. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=93)
#  18%|█▊        | 9/50 [00:38<03:32,  5.19s/it]Your max_length is set to 200, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
#  22%|██▏       | 11/50 [00:57<05:05,  7.84s/it]Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  24%|██▍       | 12/50 [01:03<04:29,  7.10s/it]Your max_length is set to 200, but your input_length is only 34. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
#  26%|██▌       | 13/50 [01:06<03:40,  5.95s/it]Your max_length is set to 200, but your input_length is only 176. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
#  28%|██▊       | 14/50 [01:11<03:25,  5.71s/it]Your max_length is set to 200, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
#  30%|███       | 15/50 [01:15<03:00,  5.17s/it]Your max_length is set to 200, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
#  32%|███▏      | 16/50 [01:19<02:41,  4.75s/it]Your max_length is set to 200, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
#  34%|███▍      | 17/50 [01:21<02:11,  3.98s/it]Your max_length is set to 200, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
#  36%|███▌      | 18/50 [01:24<01:56,  3.63s/it]Your max_length is set to 200, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
#  38%|███▊      | 19/50 [01:27<01:43,  3.34s/it]Your max_length is set to 200, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
#  40%|████      | 20/50 [01:33<02:05,  4.18s/it]Your max_length is set to 200, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
#  42%|████▏     | 21/50 [01:40<02:27,  5.09s/it]Your max_length is set to 200, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
#  44%|████▍     | 22/50 [01:42<02:00,  4.30s/it]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
#  46%|████▌     | 23/50 [01:47<02:00,  4.47s/it]Your max_length is set to 200, but your input_length is only 190. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=95)
#  48%|████▊     | 24/50 [01:52<01:59,  4.60s/it]Your max_length is set to 200, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
#  50%|█████     | 25/50 [01:58<02:04,  4.99s/it]Your max_length is set to 200, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
#  52%|█████▏    | 26/50 [02:01<01:46,  4.45s/it]Your max_length is set to 200, but your input_length is only 28. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
#  54%|█████▍    | 27/50 [02:04<01:29,  3.88s/it]Your max_length is set to 200, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
#  56%|█████▌    | 28/50 [02:06<01:16,  3.48s/it]Your max_length is set to 200, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
#  58%|█████▊    | 29/50 [02:09<01:05,  3.14s/it]Your max_length is set to 200, but your input_length is only 148. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
#  60%|██████    | 30/50 [02:13<01:08,  3.40s/it]Your max_length is set to 200, but your input_length is only 27. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
#  62%|██████▏   | 31/50 [02:15<00:59,  3.13s/it]Your max_length is set to 200, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
#  64%|██████▍   | 32/50 [02:19<01:01,  3.44s/it]Your max_length is set to 200, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
#  66%|██████▌   | 33/50 [02:23<01:01,  3.63s/it]Your max_length is set to 200, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
#  68%|██████▊   | 34/50 [02:28<01:02,  3.89s/it]Your max_length is set to 200, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
#  70%|███████   | 35/50 [02:31<00:52,  3.52s/it]Your max_length is set to 200, but your input_length is only 159. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
#  72%|███████▏  | 36/50 [02:37<01:01,  4.41s/it]Your max_length is set to 200, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
#  74%|███████▍  | 37/50 [02:45<01:11,  5.48s/it]Your max_length is set to 200, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
#  76%|███████▌  | 38/50 [02:49<01:00,  5.03s/it]Your max_length is set to 200, but your input_length is only 33. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
#  78%|███████▊  | 39/50 [02:56<01:03,  5.74s/it]Your max_length is set to 200, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
#  82%|████████▏ | 41/50 [03:06<00:49,  5.50s/it]Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  84%|████████▍ | 42/50 [03:09<00:38,  4.80s/it]Your max_length is set to 200, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
#  86%|████████▌ | 43/50 [03:13<00:31,  4.48s/it]Your max_length is set to 200, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
#  88%|████████▊ | 44/50 [03:18<00:27,  4.51s/it]Your max_length is set to 200, but your input_length is only 102. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
#  90%|█████████ | 45/50 [03:23<00:23,  4.66s/it]Your max_length is set to 200, but your input_length is only 153. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=76)
#  92%|█████████▏| 46/50 [03:29<00:21,  5.28s/it]Your max_length is set to 200, but your input_length is only 176. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=88)
#  94%|█████████▍| 47/50 [03:36<00:16,  5.61s/it]Your max_length is set to 200, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
#  96%|█████████▌| 48/50 [03:39<00:09,  4.84s/it]Your max_length is set to 200, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
#  98%|█████████▊| 49/50 [03:44<00:04,  4.83s/it]Your max_length is set to 200, but your input_length is only 42. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# 100%|██████████| 50/50 [03:46<00:00,  4.54s/it]

# %%
result_agg = rouge.compute(predictions = candidate_summaries,
                           references = article_summaries[:50], use_stemmer = True)
result_agg
# Out:
# {'rouge1': 0.30996719953066054,
#  'rouge2': 0.13784331609030942,
#  'rougeL': 0.22002456919766172,
#  'rougeLsum': 0.2213687825102751}

# %%
result_unagg = rouge.compute(predictions = candidate_summaries, references = article_summaries[:50],
                             use_stemmer = True, use_aggregator = False)

# %%
result_unagg_rsum = np.array(result_unagg["rougeLsum"])

np.argmax(result_unagg_rsum), np.argmin(result_unagg_rsum)
# Out:
# (42, 14)

# %%
act_vs_pred_summaries_df = pd.DataFrame(list(zip(candidate_summaries, article_summaries[:50])),
                                        columns = ["Predicted_Summaries", "Reference_summaries"])
act_vs_pred_summaries_df.head()
# Out:
#                                  Predicted_Summaries  \
# 0  a RESOLUTION encouraging the use of an individ...
# 1  this authorization applies to contracts for go...
# 2  the amendment to a certain joint powers agreem...
# 3  a new map indicating the boundaries of the con...
# 4  the deed was approved for open space, park, an...
#
#                                  Reference_summaries
# 0  The Civil Rights, Utilities, Economic Developm...
# 1  The Committee on Government Operations discuss...
# 2  The City Manager recommended the adoption of t...
# 3  The meeting discussed proposed ordinance 2016 ...
# 4  The meeting discussed the confirmation of an a...

# %%
print("Actual Summary")
print(act_vs_pred_summaries_df._get_value(42, "Predicted_Summaries"))

print("Reference Summary")
print(act_vs_pred_summaries_df._get_value(42, "Reference_summaries"))
# Out:
# Actual Summary
# city manager to direct airport director to provide a report on how the city will participate in discussions with the FAA to reduce helicopter noise. the recommandation is to request the City of Long Beach to direct Airport Director to provide the report on the impact of helicopter noise on the city of long beach. the report will be presented by the city's director of airports and airports.
# Reference Summary
# The meeting discussed the issue of helicopter noise in the City of Long Beach. Councilwoman Jeri Ships Key and Councilmember Gary DeLong recommended that the city manager direct the airport director to provide a report on how the city will participate in discussions with the FAA to reduce helicopter noise. This comes after the Los Angeles County Residential Helicopter Noise Relief Act was signed into law by President Obama, requiring the FAA to explore ways to reduce helicopter noise in Los Angeles County. A resident, Diamond Sievers, expressed her support for the motion and urged the council to actively participate in the upcoming FAA meetings. The motion was passed with seven votes.

# %%
print("Actual Summary")
print(act_vs_pred_summaries_df._get_value(14, "Predicted_Summaries"))

print("Reference Summary")
print(act_vs_pred_summaries_df._get_value(14, "Reference_summaries"))
# Out:
# Actual Summary
# the ordinance amending the land use district map of the city of long Beach as said map has been established and amended by amending portions of Parts 10, 16, 29 and 30 of said map, read and adopted as read. (Districts 6,8)
# Reference Summary
# The meeting discussed the proposal for zone changes for four properties to reflect their current and future use as city parks. The properties include Rosa Parks Park, Cambodian Killing Fields Memorial, NAACP Freedom Park, and Davenport Park Expansion. The rezoning is the first step in ensuring these properties remain as public parks and are recognized as part of the city's Parkland inventory in perpetuity. The proposal was unanimously recommended by the Planning Commission in February and is exempt from the California Environmental Quality Act. The City Council was asked to affirm the Planning Commission's recommendation to rezone the parks. Public comment was invited but none was given. Councilman Austin and Councilman Pierce expressed their support for the proposal. The meeting concluded with a vote on the hearing.
